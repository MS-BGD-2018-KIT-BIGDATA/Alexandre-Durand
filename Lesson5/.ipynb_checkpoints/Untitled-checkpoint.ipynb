# %%
# packages:
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing, neighbors
import statsmodels.api as sm
import urllib

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %% [markdown]
# Depuis le site de la Drees, on récupère la densité de médecin par spécialité et par région, POUR L'ANNEE 2016
# > http://www.data.drees.sante.gouv.fr/ReportFolders/reportFolders.aspx?IF_ActivePath=P,490,497,514
#
# Tab7 = DENSITÉ DE MÉDECINS par spécialité, modes d'exercice regroupés et zone d'inscription

# %%
# Convert into DataFrame object:
filename = '/Users/adurand/Documents/INFMDI721-KitDataScience/Cours5-Hackaton-Sante/rpps-medecins-tab7.csv'

df_dens = pd.read_csv(filename, sep=',', encoding='latin_1', header=3, skiprows=[5]) #, usecols=fields)

df_dens.set_index('SPECIALITE')
# Out:
#                                      Ensemble des spécialités d'exercice  \
# SPECIALITE
# FRANCE ENTIERE                                                     336.8
# FRANCE Métropolitaine                                              339.2
# DOM-COM                                                            264.0
# Alsace-Champagne-Ardenne-Lorraine                                  319.9
# Aquitaine-Limousin-Poitou-Charentes                                334.4
# Auvergne-Rhône-Alpes                                               336.9
# Bourgogne-Franche-Comté                                            294.6
# Bretagne                                                           315.7
# Centre-Val de Loire                                                268.0
# Corse                                                              298.3
# Guadeloupe                                                         267.7
# Guyane                                                             227.1
# ...

# %% [markdown]
# ### Histogramme des médecins par spécialité et par région

# %%
### Sélection des données par région:

df_dens_reg = df_dens.loc['Alsace-Champagne-Ardenne-Lorraine':'Provence-Alpes-Côte dAzur']
df_dens_reg = df_dens.iloc[3:20]
df_dens_reg.set_index('SPECIALITE')

sns.barplot(df_dens['Spécialistes'], color="navy") #, bw=1.5, cut=0)
sns.barplot(df_dens['Généralistes'], color="orange") #, bw=1.5, cut=0)

### Paramètres d'affichage :
plt.title('Densité de Médecins par région')
plt.xlabel('Région')
plt.ylabel('Médecins/100.000 habs');

df_dens_reg
# Out:
#                              SPECIALITE  Ensemble des spécialités d'exercice  \
# 3     Alsace-Champagne-Ardenne-Lorraine                                319.9
# 4   Aquitaine-Limousin-Poitou-Charentes                                334.4
# 5                  Auvergne-Rhône-Alpes                                336.9
# 6               Bourgogne-Franche-Comté                                294.6
# 7                              Bretagne                                315.7
# 8                   Centre-Val de Loire                                268.0
# 9                                 Corse                                298.3
# 10                           Guadeloupe                                267.7
# 11                               Guyane                                227.1
# 12                        Ile-de-France                                398.3
# 13                           La Réunion                                318.1
# ...

# %%
# Conversion des tailles : Pouces > Centimètres (1 in = 2.54 cm)
#df_Gal[['Father', 'Mother', 'Height']] *= 2.54

# Arrondi à l'unité pour les tailles
#df_Gal = df_Gal.round({'Father': 0, 'Mother': 0, 'Height': 0})
